# %%
import selenium
from selenium import webdriver

# %%
from selenium import webdriver


#
# 2 . html 뽑아보기
#

# 드라이버 연결 크롬
driver = webdriver.Chrome()

# url 주소
url ='https://serverrefository.tistory.com/'
driver.get(url)

# url 주소페이지 html 소스코드
driver.page_source
# Out:
# '<html lang="ko" style="--vh-offset: 45px;"><head>\n                <script src="https://connect.facebook.net/ko_KR/sdk.js?hash=0d459df43e6cb37c11f889986433c7de" async="" crossorigin="anonymous"></script><script src="https://t1.kakaocdn.net/malibu_prod/wpm.js" async=""></script><script id="facebook-jssdk" src="//connect.facebook.net/ko_KR/sdk.js#xfbml=1&amp;version=v3.2&amp;appId=360877073936113&amp;autoLogAppEvents=1"></script><script type="text/javascript">if (!window.T) { window.T = {} }\nwindow.T.config = {"TOP_SSL_URL":"https://www.tistory.com","PREVIEW":false,"ROLE":"guest","PREV_PAGE":"","NEXT_PAGE":"","BLOG":{"id":5363625,"name":"serverrefository","title":"KIM MIN WOO","isDormancy":false},"NEED_COMMENT_LOGIN":false,"COMMENT_LOGIN_CONFIRM_MESSAGE":"","LOGIN_URL":"https://www.tistory.com/auth/login/?redirectUrl=https%3A%2F%2Fserverrefository.tistory.com%2F","DEFAULT_URL":"https://serverrefository.tistory.com","USER":{"name":null,"homepage":null,"id":0,"profileImage":null},"SUBSCRIPTION":{"status":"none","isConnected":false,"isPending":false,"isWait":false,"isProcessing":false,"isNone":true},"IS_LOGIN":false,"HAS_BLOG":false,"TOP_URL":"http://www.tistory.com","JOIN_URL":"https://www.tistory.com/member/join","ROLE_GROUP":"visitor"};\nwindow.appInfo = {"domain":"tistory.com","topUrl":"https://www.tistory.com","loginUrl":"https://www.tistory.com/auth/login","logoutUrl":"https://www.tistory.com/auth/logout"};\nwindow.initData = {};\n\nwindow.TistoryBlog = {\n    basePath: "",\n    url: "https://serverrefository.tistory.com",\n    tistoryUrl: "https://serverrefository.tistory.com",\n    manageUrl: "https://serverrefository.tistory.com/manage",\n    token: "tubk+HX73c8DYxJBiYxg4keBIebNzrVG0tCAVHcLFHMJdQ+FNIdkD3Tl8Wo27nmN"\n};\nvar servicePath = "";\nvar blogURL = "";</script>\n\n                \n                \n                \n                        <!-- BusinessLicenseInfo - START -->\n        \n            <link href="https://tistory1.daumcdn.net/tistory_admin/userblog/userblog-28cdab05fd355e1560c577f1dc5d56d44d4289eb/static/plugin/BusinessLicenseInfo/style.css" rel="stylesheet" type="text/css">\n\n            <script>function switchFold(entryId) {\n    var businessLayer = document.getElementById("businessInfoLayer_" + entryId);\n\n    if (businessLayer) {\n        if (businessLayer.className.indexOf("unfold_license") > 0) {\n            businessLayer.className = "business_license_layer";\n        } else {\n            businessLayer.className = "business_license_layer unfold_license";\n        }\n    }\n}\n</script>\n\n        \n        <!-- BusinessLicenseInfo - END -->\n        <!-- DaumShow - START -->\n        <style type="text/css">#daumSearchBox {\n    height: 21px;\n    background-image: url(//i1.daumcdn.net/imgsrc.search/search_all/show/tistory/plugin/bg_search2_2.gif);\n    margin: 5px auto;\n    padding: 0;\n}\n\n#daumSearchBox input {\n    background: none;\n    margin: 0;\n    padding: 0;\n    border: 0;\n}\n\n#daumSearchBox #daumLogo {\n    width: 34px;\n    height: 21px;\n    float: left;\n    margin-right: 5px;\n    background-image: url(//i1.daumcdn.net/img-media/tistory/img/bg_search1_2_2010ci.gif);\n}\n\n#daumSearchBox #show_q {\n    background-color: transparent;\n    border: none;\n    font: 12px Gulim, Sans-serif;\n    color: #555;\n    margin-top: 4px;\n    margin-right: 15px;\n    float: left;\n}\n\n#daumSearchBox #show_btn {\n    background-image: url(//i1.daumcdn.net/imgsrc.search/search_all/show/tistory/plugin/bt_search_2.gif);\n    width: 37px;\n    height: 21px;\n    float: left;\n    margin: 0;\n    cursor: pointer;\n    text-indent: -1000em;\n}\n</style>\n\n        <!-- DaumShow - END -->\n\n<!-- System - START -->\n\n<!-- System - END -->\n\n        <!-- GoogleSearchConsole - START -->\n        \n<!-- BEGIN GOOGLE_SITE_VERIFICATION -->\n<meta name="google-site-verification" content="nK4VOpXNeJgu783fT9-r7qJQ0fuVUNRJb5uipcyVB-0">\n<!-- END GOOGLE_SITE_VERIFICATION -->\n\n        <!-- GoogleS ...
